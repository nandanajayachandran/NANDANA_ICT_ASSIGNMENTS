# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
data = pd.read_csv('data.csv')

# %%
print(data)
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
data.describe()
# Out:
#          Duration       Pulse    Maxpulse    Calories
# count   32.000000   32.000000   32.000000   30.000000
# mean    68.437500  103.500000  128.500000  304.680000
# std     70.039591    7.832933   12.998759   66.003779
# min     30.000000   90.000000  101.000000  195.100000
# 25%     60.000000  100.000000  120.000000  250.700000
# 50%     60.000000  102.500000  127.500000  291.200000
# 75%     60.000000  106.500000  132.250000  343.975000
# max    450.000000  130.000000  175.000000  479.000000

# %%
data.count()
# Out:
# Duration    32
# Date        31
# Pulse       32
# Maxpulse    32
# Calories    30
# dtype: int64

# %%
#Cleaning the data

# %%
data.shape
# Out:
# (32, 5)

# %%
data.columns
# Out:
# Index(['Duration', 'Date', 'Pulse', 'Maxpulse', 'Calories'], dtype='object')

# %%
data.dtypes
# Out:
# Duration      int64
# Date         object
# Pulse         int64
# Maxpulse      int64
# Calories    float64
# dtype: object

# %%
#Looking for null values

# %%
data.isna().sum()
# Out:
# Duration    0
# Date        1
# Pulse       0
# Maxpulse    0
# Calories    2
# dtype: int64

# %%
data[['Calories','Date']].mode()
# Out:
#    Calories          Date
# 0     300.0  '2020/12/12'

# %%
#Filling missing values

# %%
data.corr()
# Out:
#           Duration     Pulse  Maxpulse  Calories
# Duration  1.000000  0.004410  0.049959 -0.114169
# Pulse     0.004410  1.000000  0.276583  0.513186
# Maxpulse  0.049959  0.276583  1.000000  0.357460
# Calories -0.114169  0.513186  0.357460  1.000000

# %%
data['Calories'].replace([np.nan], data['Calories'].mean(), inplace=True)
data['Date'] = data['Date'].fillna(data['Date'].mode()[0])
data
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130    409.10
# 1         60  '2020/12/02'    117       145    479.00
# 2         60  '2020/12/03'    103       135    340.00
# 3         45  '2020/12/04'    109       175    282.40
# 4         45  '2020/12/05'    117       148    406.00
# 5         60  '2020/12/06'    102       127    300.00
# 6         60  '2020/12/07'    110       136    374.00
# 7        450  '2020/12/08'    104       134    253.30
# 8         30  '2020/12/09'    109       133    195.10
# 9         60  '2020/12/10'     98       124    269.00
# 10        60  '2020/12/11'    103       147    329.30
# 11        60  '2020/12/12'    100       120    250.70
# 12        60  '2020/12/12'    100       120    250.70
# 13        60  '2020/12/13'    106       128    345.30
# 14        60  '2020/12/14'    104       132    379.30
# 15        60  '2020/12/15'     98       123    275.00
# ...

# %%
#Data Visualizations

# %%
data.hist(figsize=(20,15))
plt.show()

# %%
#box plot
sns.boxplot(x=data['Duration'],y=data['Calories'])
plt.title('Duration Vs Calories')
plt.show()

# %%
sns.scatterplot(x=data['Maxpulse'],y=data['Calories'],hue=data['Duration'])
plt.title('MAXPULSE Vs CALORIES')
plt.show()

# %%
sns.boxplot(x=data['Duration'],y=data['Pulse'])
plt.title('Duration Vs Pulse')
plt.show()

# %%
sns.scatterplot(x=data['Maxpulse'],y=data['Calories'],hue=data['Date'])
plt.title('MAXPULSE Vs CALORIES')
plt.show()

# %%
sns.boxplot(x=data['Pulse'],y=data['Calories'])
plt.title('Pulse Vs Calories')
plt.show()
